# %% [markdown]
# <a href="https://colab.research.google.com/github/ricvazquez/ColabFiles/blob/main/Prueba1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hola mundo para Github')
# Out:
# Hola mundo para Github

# %%
print('Cambios')
# Out:
# Cambios
